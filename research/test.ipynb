# %%
pip install chromadb langchain openai dotenv
# Out:
# Requirement already satisfied: chromadb in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (0.5.0)
# Requirement already satisfied: langchain in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (0.2.3)
# Requirement already satisfied: openai in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (1.33.0)
# Collecting dotenv
#   Using cached dotenv-0.0.5.tar.gz (2.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [76 lines of output]
#       c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\setuptools\__init__.py:81: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#         error: subprocess-exited-with-error
#
#         Ã— python setup.py egg_info did not run successfully.
#         â”‚ exit code: 1
#         â•°â”€> [16 lines of output]
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 14, in <module>
#               File "C:\Users\ABHISHEK\AppData\Local\Temp\pip-wheel-6y0ngv54\distribute_9c7a9a0f0b5443429973ec408c18ecee\setuptools\__init__.py", line 2, in <module>
#                 from setuptools.extension import Extension, Library
#               File "C:\Users\ABHISHEK\AppData\Local\Temp\pip-wheel-6y0ngv54\distribute_9c7a9a0f0b5443429973ec408c18ecee\setuptools\extension.py", line 5, in <module>
#                 from setuptools.dist import _get_unpatched
#               File "C:\Users\ABHISHEK\AppData\Local\Temp\pip-wheel-6y0ngv54\distribute_9c7a9a0f0b5443429973ec408c18ecee\setuptools\dist.py", line 7, in <module>
#                 from setuptools.command.install import install
#               File "C:\Users\ABHISHEK\AppData\Local\Temp\pip-wheel-6y0ngv54\distribute_9c7a9a0f0b5443429973ec408c18ecee\setuptools\command\__init__.py", line 8, in <module>
#                 from setuptools.command import install_scripts
#               File "C:\Users\ABHISHEK\AppData\Local\Temp\pip-wheel-6y0ngv54\distribute_9c7a9a0f0b5443429973ec408c18ecee\setuptools\command\install_scripts.py", line 3, in <module>
#                 from pkg_resources import Distribution, PathMetadata, ensure_directory
#               File "C:\Users\ABHISHEK\AppData\Local\Temp\pip-wheel-6y0ngv54\distribute_9c7a9a0f0b5443429973ec408c18ecee\pkg_resources.py", line 1518, in <module>
#                 register_loader_type(importlib_bootstrap.SourceFileLoader, DefaultProvider)
#             AttributeError: module 'importlib._bootstrap' has no attribute 'SourceFileLoader'
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       Ã— Encountered error while generating package metadata.
#       â•°â”€> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       Traceback (most recent call last):
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\setuptools\installer.py", line 101, in _fetch_build_egg_no_warn
#           subprocess.check_call(cmd)
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\subprocess.py", line 369, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['c:\\Users\\ABHISHEK\\anaconda3\\envs\\interview\\python.exe', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', 'C:\\Users\\ABHISHEK\\AppData\\Local\\Temp\\tmpaj56duyi', '--quiet', 'distribute']' returned non-zero exit status 1.
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\ABHISHEK\AppData\Local\Temp\pip-install-uxu58ux5\dotenv_2880866020bb45d89099ba41216b304e\setup.py", line 13, in <module>
#           setup(name='dotenv',
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\setuptools\__init__.py", line 103, in setup
#           _install_setup_requires(attrs)
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\setuptools\__init__.py", line 76, in _install_setup_requires
#           _fetch_build_eggs(dist)
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\setuptools\__init__.py", line 81, in _fetch_build_eggs
#           dist.fetch_build_eggs(dist.setup_requires)
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\setuptools\dist.py", line 640, in fetch_build_eggs
#           return _fetch_build_eggs(self, requires)
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\setuptools\installer.py", line 38, in _fetch_build_eggs
#           resolved_dists = pkg_resources.working_set.resolve(
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\pkg_resources\__init__.py", line 798, in resolve
#           dist = self._resolve_dist(
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\pkg_resources\__init__.py", line 834, in _resolve_dist
#           dist = best[req.key] = env.best_match(
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\pkg_resources\__init__.py", line 1104, in best_match
#           return self.obtain(req, installer)
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\pkg_resources\__init__.py", line 1115, in obtain
#           return installer(requirement) if installer else None
#         File "c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\setuptools\installer.py", line 103, in _fetch_build_egg_no_warn
#           raise DistutilsError(str(e)) from e
#       distutils.errors.DistutilsError: Command '['c:\\Users\\ABHISHEK\\anaconda3\\envs\\interview\\python.exe', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', 'C:\\Users\\ABHISHEK\\AppData\\Local\\Temp\\tmpaj56duyi', '--quiet', 'distribute']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (0.5.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (2.7.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.1)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.18.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (8.3.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (3.10.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.1.1)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2024.6.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: coloredlogs in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.5.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.6.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pydantic>=1.9->chromadb) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from requests>=2.28->chromadb) (3.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.23.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: h11>=0.8 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: anyio in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (4.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: filelock in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.15.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from anyio->httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.2.1)
# Requirement already satisfied: pyreadline3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
import chromadb
from chromadb.config import Settings

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (0.5.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (2.7.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.1)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.18.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (8.3.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (3.10.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.1.1)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2024.6.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: coloredlogs in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.5.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.6.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pydantic>=1.9->chromadb) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from requests>=2.28->chromadb) (3.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.23.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: h11>=0.8 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: anyio in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (4.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: filelock in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.15.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from anyio->httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.2.1)
# Requirement already satisfied: pyreadline3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)

# %%
# !pip install chromadb langchain openai python-dotenv
# Out:
# Requirement already satisfied: chromadb in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (0.5.0)
# Requirement already satisfied: langchain in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (0.2.3)
# Requirement already satisfied: openai in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (1.33.0)
# Requirement already satisfied: python-dotenv in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (1.0.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (2.7.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.1)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.18.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (8.3.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from chromadb) (3.10.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from langchain) (0.2.5)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from langchain) (0.2.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from langchain) (0.1.76)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.1.1)
# Requirement already satisfied: certifi in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: coloredlogs in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.5.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.6.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pydantic>=1.9->chromadb) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.23.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (3.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abhishek\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.15.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\abhishek\anaconda3\envs\interview\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)

# %%
pip install Client
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement Client (from versions: none)
# ERROR: No matching distribution found for Client

# %%
# Load environment variables
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import TokenTextSplitter
from langchain.docstore.document import Document
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains.summarize import load_summarize_chain
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA

# %%
# Load PDF file
file_path = "data/SDG.pdf"

# %%
loader = PyPDFLoader(file_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 loader = PyPDFLoader(file_path)
#
# File c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\langchain_community\document_loaders\pdf.py:182, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images)
#     178 except ImportError:
#     179     raise ImportError(
#     180         "pypdf package not found, please install it with " "`pip install pypdf`"
#     181     )
# --> 182 super().__init__(file_path, headers=headers)
#     183 self.parser = PyPDFParser(password=password, extract_images=extract_images)
#
# File c:\Users\ABHISHEK\anaconda3\envs\interview\lib\site-packages\langchain_community\document_loaders\pdf.py:116, in BasePDFLoader.__init__(self, file_path, headers)
#     114         self.file_path = str(temp_pdf)
#     115 elif not os.path.isfile(self.file_path):
# --> 116     raise ValueError("File path %s is not a valid file or url" % self.file_path)
#
# ValueError: File path data/SDG.pdf is not a valid file or url
